# %%
! nvidia-smi
# Out:
# Thu May  4 15:02:29 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:4B:00.0     Off |                  N/A |
# | 30%   48C    P0    42W / 180W |      0MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:4C:00.0     Off |                  N/A |
# | 26%   41C    P0    42W / 180W |      0MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:4D:00.0     Off |                  N/A |
# | 27%   43C    P0    42W / 180W |      0MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:4E:00.0     Off |                  N/A |
# |  0%   46C    P0    39W / 180W |      0MiB /  8110MiB |      2%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from CUDATools import *
# Out:
# Available Devices:
#   Device 0: GeForce GTX 1080
#   Device 1: GeForce GTX 1080
#   Device 2: GeForce GTX 1080
#   Device 3: GeForce GTX 1080
# Select device number: 0
# Using device 0: GeForce GTX 1080

# %%
# %pylab inline
#from pycuda import gpuarray, autoinit
from pyfft.cuda import Plan as plan1
from skcuda.fft import Plan as plan2
from skcuda.fft import fft as skfft
from reikna.fft import FFT
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !nvidia-smi
# Out:
# Thu May  4 15:02:39 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:4B:00.0     Off |                  N/A |
# | 31%   48C    P2    40W / 180W |    224MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:4C:00.0     Off |                  N/A |
# | 26%   42C    P0    42W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:4D:00.0     Off |                  N/A |
# | 27%   45C    P0    43W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:4E:00.0     Off |                  N/A |
# | 30%   48C    P0    43W / 180W |      2MiB /  8110MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0     10679    C   /usr/bin/python                                222MiB |
# +-----------------------------------------------------------------------------+

# %%
from reikna.cluda import cuda_api
api = cuda_api()
thr = api.Thread(ctx)
print thr._context
print ctx
# Out:
# <pycuda._driver.Context object at 0x7fd897f9e5f0>
# <pycuda._driver.Context object at 0x7fd897f9e5f0>

# %%
! nvidia-smi
# Out:
# Thu May  4 15:02:39 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:4B:00.0     Off |                  N/A |
# | 31%   48C    P2    40W / 180W |    224MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:4C:00.0     Off |                  N/A |
# | 26%   42C    P0    42W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:4D:00.0     Off |                  N/A |
# | 27%   45C    P0    43W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:4E:00.0     Off |                  N/A |
# | 30%   48C    P0    43W / 180W |      2MiB /  8110MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0     10679    C   /usr/bin/python                                222MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### 1,2,3 Dimension

# %%
prec = 16 # bytes
npPrec = [np.float32,np.float64]
npCPrec = [np.complex64,np.complex128]
N3D = [2**i for i in range(5,10)]
sizeN3D = [2**(3*i)*prec/2.0**30 for i in range(5,10)]

N2D = [2**i for i in range(10,14)]
sizeN2D = [2**(2*i)*prec/2.0**30 for i in range(10,14)]

N1D = [2**i for i in range(20,28)]
sizeN1D = [2**(i)*prec/2.0**30 for i in range(20,28)]

print '## 1D \n',N1D ,'\n', sizeN1D
print '## 2D \n',N2D ,'\n', sizeN2D
print '## 3D  \n',N3D ,'\n', sizeN3D
# Out:
# ## 1D
# [1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728]
# [0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1.0, 2.0]
# ## 2D
# [1024, 2048, 4096, 8192]
# [0.015625, 0.0625, 0.25, 1.0]
# ## 3D
# [32, 64, 128, 256, 512]
# [0.00048828125, 0.00390625, 0.03125, 0.25, 2.0]

# %%
from pycuda import curandom
randomGPU = curandom.XORWOWRandomNumberGenerator()

# %%
# real = random.gen_uniform(N1D[0],npPrec[0])
real = sin(linspace(0,2*pi,N1D[0]))

# %%
real_gpu = gpuarray.to_gpu(real.astype(npCPrec[0]))
real2_gpu = gpuarray.to_gpu(real.astype(npCPrec[0]))

# %%
plot(real2_gpu.get().real)

# %%
myFFTPlan = plan1(N1D[0],dtype=npCPrec[0])

# %%
myFFTPlan.execute(real_gpu)

# %%
#fftplan2 = plan2(N1D[0],npCPrec[0],npCPrec[0])
fftplan2 = plan2(N1D[0],npCPrec[0],npCPrec[0])

# %%
fftPlan3 = FFT(real_gpu)

# %%
reikFFT = fftPlan3.compile(thr)

# %%
plot(abs(real_gpu.get()))

# %%
fftreal = fft.fft(real)

# %%
plot(abs(fftreal))

# %%
plot(abs(fftreal-real_gpu.get()))

# %%
skfft(real2_gpu, real_gpu, fftplan2)
#skfft(real2_gpu, fftplan2)

# %%
plot(abs(real_gpu.get()))

# %%
plot(abs(fftreal-real_gpu.get()))

# %%
reikFFT(real_gpu, real2_gpu )
#reikFFT(real2_gpu )
# Out:
# [None, None, None]

# %%
plot(abs(real_gpu.get()))

# %%
plot(abs(fftreal-real_gpu.get()))

# %%
real_gpu.gpudata.free()

# %%
real2_gpu.gpudata.free()

# %%
getFreeMemory()
# Out:
# Free Global Memory: 7812.000000 Mbytes
# 7812.0

# %%
! nvidia-smi
# Out:
# Thu May  4 13:34:49 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:4B:00.0     Off |                  N/A |
# | 31%   50C    P2    40W / 180W |    302MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:4C:00.0     Off |                  N/A |
# | 26%   43C    P2    34W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:4D:00.0     Off |                  N/A |
# | 28%   46C    P2    34W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:4E:00.0     Off |                  N/A |
# | 29%   47C    P2    35W / 180W |      2MiB /  8110MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0      9672    C   /usr/bin/python                                300MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
#     Now in 'A_GPU' it is stored its trandsform. I mean we ocverwrite the original array with the FFT, if you put two arguments this overwrite is avoided.

# %% [markdown]
# ### 3 Dimensions and Performance

# %%
from time import time
import pycuda.driver as drv
from pycuda import gpuarray
start = drv.Event()
end = drv.Event()

# %%
dimensions = [64,128,256,512]
prec = complex128

# %%
timeCPU = []
timeGPU1 = []
timeGPU2 = []
timeGPU3 = []
timeCPY = []

# %%
samples = 100

# %%
for d in dimensions:
    A_CPU = random.random((d,d,d)).astype(prec)
    start.record()
    A_GPU = gpuarray.to_gpu(A_CPU)
    B_GPU = gpuarray.to_gpu(A_CPU)
    end.record()
    end.synchronize()
    timeCPY.append(start.time_till(end)*1e-3)
    
    
    t = time()
    for i in range(samples): FFT_A_CPU = fft.fft(A_CPU)
    timeCPU.append(time()-t)
    
    myFFTPlan = plan1((d,d,d),prec)
    myFFTPlan2  = plan2((d,d,d),prec,prec)
    myFFTPlan3 = FFT(A_GPU)
    reikfft = myFFTPlan3.compile(thr)
    
    start.record()
    for i in range(samples): myFFTPlan.execute(A_GPU, B_GPU)
    end.record()
    end.synchronize()
    secs = start.time_till(end)*1e-3
    timeGPU1.append(secs)
    
    start.record()
    for i in range(samples): skfft(A_GPU, B_GPU,myFFTPlan2)
    end.record()
    end.synchronize()
    secs = start.time_till(end)*1e-3
    timeGPU2.append(secs)
    
    start.record()
    for i in range(samples): reikfft(A_GPU, B_GPU)
    end.record()
    end.synchronize()
    secs = start.time_till(end)*1e-3
    timeGPU3.append(secs)
    
    A_GPU.gpudata.free()
    B_GPU.gpudata.free()
    del myFFTPlan,myFFTPlan2, myFFTPlan3,reikfft
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-35-0118b17abcd8> in <module>()
#      16     myFFTPlan2  = plan2((d,d,d),prec,prec)
#      17     myFFTPlan3 = FFT(A_GPU)
# ---> 18     reikfft = myFFTPlan3.compile(thr)
#      19
#      20     start.record()
#
# /usr/local/lib/python2.7/dist-packages/reikna/core/computation.pyc in compile(self, thread, fast_math)
#     196         """
#     197         translator = Translator.identity()
# --> 198         return self._get_plan(self._tr_tree, translator, thread, fast_math).finalize()
#     199
#     200     def _build_plan(self, plan_factory, device_params, *args):
#
# /usr/local/lib/python2.7/dist-packages/reikna/core/computation.pyc in finalize(self)
#     488             type_ = self._internal_annotations[name].type
#     489             new_buf = self._thread.temp_array(
# --> 490                 type_.shape, type_.dtype, strides=type_.strides, dependencies=dependent_buffers)
#     491             internal_args[name] = new_buf
#     492             all_buffers.append(new_buf)
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/api.pyc in temp_array(self, shape, dtype, strides, dependencies)
#     269         :py:class:`~reikna.cluda.tempalloc.TemporaryManager`.
#     270         """
# --> 271         return self.temp_alloc.array(shape, dtype, strides=strides, dependencies=dependencies)
#     272
#     273     def empty_like(self, arr):
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/tempalloc.pyc in array(self, shape, dtype, strides, dependencies)
#      69
#      70         dependencies = extract_dependencies(dependencies)
# ---> 71         self._allocate(new_id, allocator.size, dependencies, self._pack_on_alloc)
#      72         self._arrays[new_id] = weakref.ref(array, lambda _: self.free(new_id))
#      73
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/tempalloc.pyc in _allocate(self, new_id, size, dependencies, pack)
#     174         else:
#     175             # If not, find a real allocation using the greedy algorithm.
# --> 176             self._fast_add(new_id, size, dep_set)
#     177
#     178     def _fast_add(self, new_id, size, dep_set):
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/tempalloc.pyc in _fast_add(self, new_id, size, dep_set)
#     198         else:
#     199             # If no suitable real allocation is found, create a new one.
# --> 200             buf = self._thr.allocate(size)
#     201             real_id = self._real_id_counter
#     202             self._real_id_counter += 1
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/cuda.pyc in allocate(self, size)
#     117
#     118     def allocate(self, size):
# --> 119         return Buffer(size)
#     120
#     121     def array(self, shape, dtype, strides=None, allocator=None):
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/cuda.pyc in __init__(self, size)
#      54
#      55     def __init__(self, size):
# ---> 56         self._buffer = cuda.mem_alloc(size)
#      57         self.size = size
#      58
#
# MemoryError: cuMemAlloc failed: out of memory

# %%
A_GPU.gpudata.free()
B_GPU.gpudata.free()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1d2e00aec70c> in <module>()
# ----> 1 A_GPU.gpudata.free()
#       2 B_GPU.gpudata.free()
#
# NameError: name 'A_GPU' is not defined

# %%
# !nvidia-smi
# Out:
# Thu May  4 15:02:54 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:4B:00.0     Off |                  N/A |
# | 31%   50C    P2    40W / 180W |    228MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:4C:00.0     Off |                  N/A |
# | 26%   42C    P8     7W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:4D:00.0     Off |                  N/A |
# | 27%   44C    P8     7W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:4E:00.0     Off |                  N/A |
# | 30%   47C    P8    13W / 180W |      2MiB /  8110MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0     10679    C   /usr/bin/python                                226MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## reikna

# %%
! nvidia-smi
# Out:
# Thu May  4 15:02:58 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.39                 Driver Version: 375.39                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:4B:00.0     Off |                  N/A |
# | 31%   50C    P2    40W / 180W |    228MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:4C:00.0     Off |                  N/A |
# | 26%   42C    P8     7W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:4D:00.0     Off |                  N/A |
# | 27%   44C    P8     7W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:4E:00.0     Off |                  N/A |
# | 30%   47C    P8    13W / 180W |      2MiB /  8110MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |    0     10679    C   /usr/bin/python                                226MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# A_CPU = random.random((512,512,512)).astype(prec)

# %% [markdown]
# myFFTPlan = plan1(A_CPU.shape,prec)

# %% [markdown]
# A_GPU = gpuarray.to_gpu(A_CPU)

# %% [markdown]
# myFFTPlan3 = FFT(A_GPU)
# reikfft = myFFTPlan3.compile(thr)

# %% [markdown]
# B_GPU = gpuarray.to_gpu(A_CPU)

# %% [markdown]
# start.record()
# for i in range(samples): myFFTPlan.execute(A_GPU)
# end.record()
# end.synchronize()
# start.time_till(end)*1e-3
# timeGPU1.append(start.time_till(end)*1e-3)

# %%
getFreeMemory()
# Out:
# Free Global Memory: 7886.000000 Mbytes
# 7886.0

# %%
d=512
samples=100

# %%
A_CPU = random.random((d,d,d)).astype(prec)
A_GPU = gpuarray.to_gpu(A_CPU)
B_GPU = gpuarray.to_gpu(A_CPU)

# %%
#myFFTPlan = plan1((d,d,d),prec)
#myFFTPlan2  = plan2((d,d,d),prec,prec)
myFFTPlan3 = FFT(A_GPU)
reikfft = myFFTPlan3.compile(thr)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-19-4bed797d3223> in <module>()
#       2 #myFFTPlan2  = plan2((d,d,d),prec,prec)
#       3 myFFTPlan3 = FFT(A_GPU)
# ----> 4 reikfft = myFFTPlan3.compile(thr)
#
# /usr/local/lib/python2.7/dist-packages/reikna/core/computation.pyc in compile(self, thread, fast_math)
#     196         """
#     197         translator = Translator.identity()
# --> 198         return self._get_plan(self._tr_tree, translator, thread, fast_math).finalize()
#     199
#     200     def _build_plan(self, plan_factory, device_params, *args):
#
# /usr/local/lib/python2.7/dist-packages/reikna/core/computation.pyc in finalize(self)
#     488             type_ = self._internal_annotations[name].type
#     489             new_buf = self._thread.temp_array(
# --> 490                 type_.shape, type_.dtype, strides=type_.strides, dependencies=dependent_buffers)
#     491             internal_args[name] = new_buf
#     492             all_buffers.append(new_buf)
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/api.pyc in temp_array(self, shape, dtype, strides, dependencies)
#     269         :py:class:`~reikna.cluda.tempalloc.TemporaryManager`.
#     270         """
# --> 271         return self.temp_alloc.array(shape, dtype, strides=strides, dependencies=dependencies)
#     272
#     273     def empty_like(self, arr):
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/tempalloc.pyc in array(self, shape, dtype, strides, dependencies)
#      69
#      70         dependencies = extract_dependencies(dependencies)
# ---> 71         self._allocate(new_id, allocator.size, dependencies, self._pack_on_alloc)
#      72         self._arrays[new_id] = weakref.ref(array, lambda _: self.free(new_id))
#      73
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/tempalloc.pyc in _allocate(self, new_id, size, dependencies, pack)
#     174         else:
#     175             # If not, find a real allocation using the greedy algorithm.
# --> 176             self._fast_add(new_id, size, dep_set)
#     177
#     178     def _fast_add(self, new_id, size, dep_set):
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/tempalloc.pyc in _fast_add(self, new_id, size, dep_set)
#     198         else:
#     199             # If no suitable real allocation is found, create a new one.
# --> 200             buf = self._thr.allocate(size)
#     201             real_id = self._real_id_counter
#     202             self._real_id_counter += 1
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/cuda.pyc in allocate(self, size)
#     117
#     118     def allocate(self, size):
# --> 119         return Buffer(size)
#     120
#     121     def array(self, shape, dtype, strides=None, allocator=None):
#
# /usr/local/lib/python2.7/dist-packages/reikna/cluda/cuda.pyc in __init__(self, size)
#      54
#      55     def __init__(self, size):
# ---> 56         self._buffer = cuda.mem_alloc(size)
#      57         self.size = size
#      58
#
# MemoryError: cuMemAlloc failed: out of memory

# %%
timeCPU = [0.30910706520080566,
  2.3439650535583496,
  18.283607006072998,
  167.26681685447693]
timeGPU1 = [0.02954729652404785, 0.23331715393066407, 2.7928020019531252,21.537302734375]
timeGPU2 = [0.022404096603393556, 0.13823385620117187, 1.1437608642578125, 12.9235673828125]
timeGPU3 = [0.03757875061035156, 0.2610584106445313, 2.99683544921875]
timeCPY = [0.012605376243591308,
  0.022300512313842773,
  0.1704000244140625,
  1.3564984130859374]

# %% [markdown]
# t = time()
# for i in range(samples): FFT_A_CPU = fft.fft(A_CPU)
# timeCPU.append(time()-t)

# %%
timeCPU, timeGPU1, timeGPU2, timeGPU3, timeCPY
# Out:
# ([0.30910706520080566,
#   2.3439650535583496,
#   18.283607006072998,
#   167.26681685447693],
#  [0.02954729652404785,
#   0.23331715393066407,
#   2.7928020019531252,
#   21.537302734375],
#  [0.022404096603393556, 0.13823385620117187, 1.1437608642578125],
#  [0.03757875061035156, 0.2610584106445313, 2.99683544921875],
#  [0.012605376243591308,
#   0.022300512313842773,
#   0.1704000244140625,
#   1.3564984130859374])

# %%
start.record()
for i in range(samples): myFFTPlan.execute(A_GPU, B_GPU)
end.record()
end.synchronize()
secs = start.time_till(end)*1e-3
timeGPU1.append(secs)

# %%
start.record()
for i in range(samples): skfft(A_GPU, B_GPU,myFFTPlan2)
end.record()
end.synchronize()
secs = start.time_till(end)*1e-3
timeGPU2.append(secs)

# %% [markdown]
# timeCPU.append(5202.7731320858)

# %% [markdown]
# timeCPU = [4.00489616394043,
#  47.76098108291626,
#  364.4098560810089,
#  5202.7731320858]

# %%
timeGPU1, dimensions
# Out:
# ([0.02954729652404785,
#   0.23331715393066407,
#   2.7928020019531252,
#   21.537302734375],
#  [64, 128, 256, 512])

# %%
timeGPU2
# Out:
# [0.022404096603393556,
#  0.13823385620117187,
#  1.1437608642578125,
#  12.9235673828125]

# %%
figure(0,figsize=(9,6),dpi=250)
plot(dimensions,timeGPU1,'r*-',label='GPUpyfft')
plot(dimensions,timeGPU2,'m*-',label='GPUscikits')
plot(dimensions[:-1],timeGPU3,'y*-',label='GPUreikna')

plot(dimensions,timeCPU,'g*-',label='CPU Numpy')
plot(dimensions[:-1],2*array(timeCPY[:-1]),'b*-',label='CPU2GPU')
plt.xticks(dimensions, dimensions, rotation='vertical')
ylabel('Time')
title('GeForce GTX 1080 Double (100 samples)')
plt.legend(loc=2,labelspacing=0.5,fancybox=True, handlelength=3.5, borderaxespad=0.25, borderpad=0.25)

# %%
figure(0,figsize=(9,6),dpi=250)
loglog(dimensions,timeGPU1,'r*-',label='GPUpyfft')
loglog(dimensions,timeGPU2,'m*-',label='GPUscikits')
loglog(dimensions[:-1],timeGPU3,'y*-',label='GPUreikna')

loglog(dimensions,timeCPU,'g*-',label='CPU Numpy')
loglog(dimensions[:-1],2*array(timeCPY[:-1]),'b*-',label='CPU2GPU')
plt.xticks(dimensions, dimensions, rotation='vertical')
ylabel('Time')
title('GeForce GTX 1080 Double samples 100')
plt.legend(loc=2,labelspacing=0.5,fancybox=True, handlelength=3.5, borderaxespad=0.25, borderpad=0.25)
xlim([60,560])
# Out:
# (60, 560)

# %%
figure(0,figsize=(9,6),dpi=250)
plot(dimensions,array(timeCPU)/array(timeGPU1),'r*-',label='GPUpyfft')
plot(dimensions,array(timeCPU)/array(timeGPU2),'m*-',label='GPUscikits')
plot(dimensions[:-1],array(timeCPU[:-1])/array(timeGPU3),'g*-',label='GPUreikna')
#plot([64,128,256,512],timeCPU,'g*-',label='CPU')
#plot(dimensions,2*array(timeCPY),'b*-',label='CPU2GPU')
plt.xticks([64,128,256,512], [64,128,256,512], rotation='vertical')
ylabel('SpeedUP')
title('GeForce GTX 1080 Double (100 samples)')
plt.legend(loc=2,labelspacing=0.5,fancybox=True, handlelength=3.5, borderaxespad=0.25, borderpad=0.25)
xlim([60,560])
# Out:
# (60, 560)

# %% [markdown]
# |Points fp64|size 1D (MB)|size 2D (MB)|size 3D (MB)|
# |:---:|:---:|:---:|:---:|
# |128|0.001|0.125|16|
# |256|0.002|0.5|128|
# |512|0.004|2|1024|
# |1024|0.008|8|8192|
# |4096|0.031|128|512G!|
# |32768|0.25|8192|

# %%
figure(0,figsize=(9,6),dpi=250)
plot([64,128,256,512],timeGPU1,'r*-',label='GPUpyfft')
plot(dimensions,timeGPU2,'m*-',label='GPUscikits')
plot(dimensions,timeGPU3,'y*-',label='GPUreikna')
plot([64,128,256,512],timeCPU,'g*-',label='CPU Numpy')
plot(dimensions,2*array(timeCPY),'b*-',label='CPU2GPU')
plt.xticks([64,128,256,512], [64,128,256,512], rotation='vertical')
ylabel('Time')
title('GeForce GTX 780 Single (1000 samples)')
plt.legend(loc=2,labelspacing=0.5,fancybox=True, handlelength=3.5, borderaxespad=0.25, borderpad=0.25)
#xlim([60,262])

# %%
figure(0,figsize=(9,6),dpi=250)
plot([64,128,256,512],array(timeCPU)/array(timeGPU1),'r*-',label='GPUpyfft')
plot(dimensions,array(timeCPU[0:3])/array(timeGPU2),'m*-',label='GPUscikits')
plot(dimensions,array(timeCPU[0:3])/array(timeGPU3),'g*-',label='GPUreikna')
#plot([64,128,256,512],timeCPU,'g*-',label='CPU')
#plot(dimensions,2*array(timeCPY),'b*-',label='CPU2GPU')
plt.xticks([64,128,256,512], [64,128,256,512], rotation='vertical')
ylabel('SpeedUP')
title('GeForce GTX 780 Single (1000 samples)')
plt.legend(loc=2,labelspacing=0.5,fancybox=True, handlelength=3.5, borderaxespad=0.25, borderpad=0.25)

# %%
figure(0,figsize=(9,6),dpi=250)
loglog([64,128,256,512],timeGPU1,'r*-',label='GPUpyfft')
loglog(dimensions,timeGPU2,'m*-',label='GPUscikits')
loglog(dimensions,timeGPU3,'m*-',label='GPUreikna')
loglog([64,128,256,512],timeCPU,'g*-',label='CPU Numpy')
loglog(dimensions,2*array(timeCPY),'b*-',label='CPU2GPU')
plt.xticks([64,128,256,512], [64,128,256,512], rotation='vertical')
ylabel('Time')
title('GeForce GTX 780 Single (1000 samples)')
plt.legend(loc=2,labelspacing=0.5,fancybox=True, handlelength=3.5, borderaxespad=0.25, borderpad=0.25)

# %% [markdown]
# # Results

# %%
# %%HTML
# <img src="data:image/png;base64,..."/>
#
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
# Out:
# <img src="data:image/png;base64,..."/>
#
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>

# %%
# %%HTML
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
# Out:
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>

# %%
# %%HTML
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..." />
# Out:
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..."/>
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# A_GPU.gpudata.free()

# %% [markdown]
# ## scikit.cuda

# %% [markdown]
# # pyCula

# %% [markdown]
# ### QUTIP

# %%
# %load_ext version_information
# %version_information numpy, scipy, matplotlib, sympy, pycuda, pycula,reikna, skcuda

# %%
#### Single
print timeGPU1 #pyfft
print timeGPU2 # scikits
print timeGPU3 # reikna
